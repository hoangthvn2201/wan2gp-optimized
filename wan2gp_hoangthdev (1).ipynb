# %% [markdown]
# # Wan2GP on Google Colab
#
# Sets up [Wan2GP](https://github.com/deepbeepmeep/Wan2GP) in a fresh GPU-backed Colab session.
#
# Run the cells in order to prepare the runtime, install dependencies, and launch the Gradio interface. Click on the link in the output from the last cell to launch the app in your browser.
#
# > **Colab VRAM note:** the free tier usually assigns a 15 GB T4 GPU. Most Wan2GP models exceed that budget; the Wan 2.2 TextImage2Video FastWan model works, producing roughly a 5 second 480p clip in about 8 minutes.

# %% [markdown]
# ## 1. Confirm the accelerator
#
# Choose `Runtime → Change runtime type` and select **GPU** before running anything else.
#
# If this cell raises an error, go back to `Runtime → Change runtime type`, pick **GPU** and save.

# %%
import subprocess

try:
    subprocess.run(['nvidia-smi'], check=True)
except Exception as exc:
    raise RuntimeError(
        'GPU not detected. In Colab, open Runtime → Change runtime type, select GPU (or TPU if GPUs are unavailable), save, then rerun this cell.'
    ) from exc

# %% [markdown]
# ## 2. Configure the workspace path
#
# Choose where Wan2GP should be installed. Update `WAN2GP_ROOT` if you prefer a different location.

# %%
from pathlib import Path

WAN2GP_ROOT = Path('/content/wan2gp').resolve()
print(f'Wan2GP will be installed to: {WAN2GP_ROOT}')
# Out:
# Wan2GP will be installed to: /content/wan2gp

# %% [markdown]
# ## 3. Download or update Wan2GP
#
# Clone the repository if it is not present yet; otherwise pull the latest changes.

# %%
import subprocess

repo_url = 'https://github.com/deepbeepmeep/Wan2GP.git'
if WAN2GP_ROOT.exists():
    print('Repository already exists. Pulling latest changes...')
    subprocess.run(['git', '-C', str(WAN2GP_ROOT), 'pull'], check=True)
else:
    subprocess.run(['git', 'clone', repo_url, str(WAN2GP_ROOT)], check=True)

# %% [markdown]
# ## 4. Install system dependencies
#
# Install shared libraries needed for video and audio processing. If you see a warning about skipping an extra repository, it is safe to ignore.

# %%
import os, subprocess

env = os.environ.copy()
env['DEBIAN_FRONTEND'] = 'noninteractive'

subprocess.run(['sudo', 'apt-get', 'update', '-qq'], check=True, env=env)
subprocess.run([
    'sudo', 'apt-get', 'install', '-y', '--no-install-recommends',
    'ffmpeg', 'libglib2.0-0', 'libgl1', 'libportaudio2'
], check=True, env=env)
# Out:
# CompletedProcess(args=['sudo', 'apt-get', 'install', '-y', '--no-install-recommends', 'ffmpeg', 'libglib2.0-0', 'libgl1', 'libportaudio2'], returncode=0)

# %% [markdown]
# ## 5. Install Python dependencies
#
# Install PyTorch, xformers and Wan2GP's Python packages.

# %%
import os, subprocess, sys

env = os.environ.copy()
env.setdefault('DEBIAN_FRONTEND', 'noninteractive')

subprocess.run([sys.executable, '-m', 'pip', 'install', '--upgrade', 'pip', 'setuptools', 'wheel'], check=True, env=env)
# subprocess.run([sys.executable, '-m', 'pip', 'install', 'torch==2.8.0', 'torchvision', 'torchaudio', '--index-url', 'https://download.pytorch.org/whl/cu128'], check=True, env=env)
subprocess.run([sys.executable, '-m', 'pip', 'install',
    '--force-reinstall', '--no-deps',
    'torch==2.8.0', 'torchvision==0.23.0', 'torchaudio==2.8.0',
    '--index-url', 'https://download.pytorch.org/whl/cu128'], check=True, env=env)

subprocess.run([sys.executable, "-m", "pip", "install", "xformers==0.0.32.post2", "--index-url", "https://download.pytorch.org/whl/cu128"],
               check=True, env=env)
subprocess.run([sys.executable, '-m', 'pip', 'install', '-r', str(WAN2GP_ROOT / 'requirements.txt')], check=True, env=env)
# Out:
# CompletedProcess(args=['/usr/bin/python3', '-m', 'pip', 'install', '-r', '/content/wan2gp/requirements.txt'], returncode=0)

# %% [markdown]
# ## 5b. Force a headless matplotlib backend
#
# Ensure Wan2GP's preprocessing tools use the headless Agg backend so Step 6 launches cleanly in Colab.

# %%
from pathlib import Path

# Replace the TkAgg backend with the headless Agg backend if present.
target = WAN2GP_ROOT / 'preprocessing/matanyone/tools/interact_tools.py'
needle = "matplotlib.use('TkAgg')"
replacement = "matplotlib.use('Agg')"

if not target.exists():
    print(f'Skipping: {target} not found.')
else:
    text = target.read_text()
    if replacement in text:
        print('Agg backend already set; no change needed.')
    elif needle in text:
        target.write_text(text.replace(needle, replacement, 1))
        print('Replaced TkAgg with Agg in interact_tools.py.')
    else:
        print('Backend call not found; no change made.')
# Out:
# Replaced TkAgg with Agg in interact_tools.py.

# %% [markdown]
# ## 6. Launch Wan2GP
#
# Run the Gradio interface. You will find the gradio link in the output. Click on the link to access the UI. Keep the cell running to stay connected; stop it with the square **Stop** button when you are finished.

# %%
import os, subprocess, sys, threading, time

env = os.environ.copy()
env.setdefault('WAN_CACHE_DIR', str(WAN2GP_ROOT / 'models'))
cmd = [
    sys.executable,
    '-u',
    'wgp.py',
    '--listen',
    '--server-port', '7860',
    '--share',
    '--profile', '5',
]
print('Launching Wan2GP…')
process = subprocess.Popen(
    cmd,
    cwd=str(WAN2GP_ROOT),
    env=env,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1,
)
stop_event = threading.Event()

def keepalive():
    while not stop_event.is_set():
        time.sleep(45)
        if stop_event.is_set():
            break
        print('[keepalive] Notebook cell still running…')

keepalive_thread = threading.Thread(target=keepalive, daemon=True)
keepalive_thread.start()

try:
    for line in iter(process.stdout.readline, ''):
        if not line:
            break
        print(line, end='')
except KeyboardInterrupt:
    print('Stopping Wan2GP…')
    process.terminate()
finally:
    stop_event.set()
    process.wait()
    keepalive_thread.join(timeout=1)
    print(f'Wan2GP stopped (return code: {process.returncode}).')
# Out:
# Launching Wan2GP…
# [keepalive] Notebook cell still running…
# [GGUF][llama.cpp CUDA] kernels unavailable, using fallback
# [Quanto][INT8] Injected int8 kernels ACTIVE (backend=triton).
# Loaded plugin: Motion Designer (from motion_designer)
# * Running on local URL:  http://0.0.0.0:7860
# * Running on public URL: https://2fbb5badd271c91b84.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [FlashVSR] Auto backend cannot use SpargeAttn (recommended, best quality especially when there is motion): FlashVSR sparse attention requirements are not satisfied. Backend: SpargeAttn (recommended, best quality especially when there is motion). Missing: SpargeAttn. Install them from docs/INSTALLATION.md and restart WanGP. Install SpargeAttn for better FlashVSR quality.
# [FlashVSR] Auto backend trying Triton Sparse Attention.
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# Loading Model 'ckpts/ltx-2.5-22b-distilled_diffusion_model_int8_convrot.safetensors' ...
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# Loading Text Encoder 'ckpts/gemma4-12b-ltx-v1/gemma4-12b-ltx-v1_bf16.safetensors' ...
# ************ Memory Management for the GPU Poor (mmgp 3.7.12) by DeepBeepMeep ************
# Pinning data of 'transformer' to reserved RAM
# [keepalive] Notebook cell still running…
# The whole model was pinned to reserved RAM: 84 large blocks spread across 18590.42 MB
# Hooked to model 'transformer' (X0Model)
# Pinning data of 'text_encoder' to reserved RAM
# Tied weights of 1920.00 MB detected: model.embed_tokens.weight <-> lm_head.weight
# The whole model was pinned to reserved RAM: 97 large blocks spread across 22711.47 MB
# Hooked to model 'text_encoder' (Gemma4UnifiedForCausalLM)
# Pinning data of 'text_embedding_projection' to reserved RAM
# The whole model was pinned to reserved RAM: 4 large blocks spread across 2333.00 MB
# Hooked to model 'text_embedding_projection' (GemmaFeaturesExtractorProjLinear)
# Pinning data of 'vae' to reserved RAM
# The whole model was pinned to reserved RAM: 4 large blocks spread across 776.61 MB
# Hooked to model 'vae' (VideoDecoder)
# Pinning data of 'video_encoder' to reserved RAM
# The whole model was pinned to reserved RAM: 3 large blocks spread across 608.32 MB
# Hooked to model 'video_encoder' (VideoEncoder)
# Pinning data of 'audio_encoder' to reserved RAM
# The whole model was pinned to reserved RAM: 1 large blocks spread across 64.00 MB
# Hooked to model 'audio_encoder' (AudioEncoder)
# Pinning data of 'audio_decoder' to reserved RAM
# The whole model was pinned to reserved RAM: 1 large blocks spread across 64.00 MB
# Hooked to model 'audio_decoder' (AudioDecoder)
# Pinning data of 'vocoder' to reserved RAM
# The whole model was pinned to reserved RAM: 1 large blocks spread across 246.21 MB
# Hooked to model 'vocoder' (VocoderWithBWE)
# Pinning data of 'spatial_upsampler' to reserved RAM
# [keepalive] Notebook cell still running…
# The whole model was pinned to reserved RAM: 5 large blocks spread across 952.85 MB
# Hooked to model 'spatial_upsampler' (LatentUpsampler)
# Pinning data of 'video_embeddings_connector' to reserved RAM
# The whole model was pinned to reserved RAM: 8 large blocks spread across 1540.25 MB
# Hooked to model 'video_embeddings_connector' (Embeddings1DConnector)
# Pinning data of 'audio_embeddings_connector' to reserved RAM
# The whole model was pinned to reserved RAM: 2 large blocks spread across 386.13 MB
# Hooked to model 'audio_embeddings_connector' (Embeddings1DConnector)
# [Quanto][INT8] Injected Triton int8 kernels are being used.
#
#   0%|          | 0/8 [00:00<?, ?steps/s]
#  12%|█▎        | 1/8 [00:05<00:41,  5.89s/steps]
#  25%|██▌       | 2/8 [00:07<00:20,  3.44s/steps]
#  38%|███▊      | 3/8 [00:09<00:13,  2.64s/steps]
#  50%|█████     | 4/8 [00:10<00:09,  2.25s/steps]
#  62%|██████▎   | 5/8 [00:12<00:06,  2.04s/steps]
#  75%|███████▌  | 6/8 [00:14<00:03,  1.91s/steps]
#  88%|████████▊ | 7/8 [00:15<00:01,  1.83s/steps]
# 100%|██████████| 8/8 [00:17<00:00,  1.79s/steps]
# 100%|██████████| 8/8 [00:17<00:00,  2.21s/steps]
#
# [keepalive] Notebook cell still running…
#   0%|          | 0/3 [00:00<?, ?steps/s]
#  33%|███▎      | 1/3 [00:04<00:09,  4.74s/steps]
#  67%|██████▋   | 2/3 [00:06<00:03,  3.25s/steps]
# 100%|██████████| 3/3 [00:09<00:00,  2.77s/steps]
# 100%|██████████| 3/3 [00:09<00:00,  3.05s/steps]
# New video saved to Path: outputs/2026-08-12-14h55m06s_seed881972524_A warm sunny backyard. The camera starts in a tight cinematic close-up of a woman and a man in their.mp4
# [keepalive] Notebook cell still running…
#
#   0%|          | 0/8 [00:00<?, ?steps/s]
#  12%|█▎        | 1/8 [00:04<00:29,  4.27s/steps]
#  25%|██▌       | 2/8 [00:06<00:16,  2.78s/steps]
#  38%|███▊      | 3/8 [00:07<00:11,  2.30s/steps]
#  50%|█████     | 4/8 [00:09<00:08,  2.07s/steps]
#  62%|██████▎   | 5/8 [00:11<00:05,  1.94s/steps]
#  75%|███████▌  | 6/8 [00:12<00:03,  1.85s/steps]
#  88%|████████▊ | 7/8 [00:14<00:01,  1.79s/steps]
# 100%|██████████| 8/8 [00:16<00:00,  1.76s/steps]
# 100%|██████████| 8/8 [00:16<00:00,  2.02s/steps]
#
#   0%|          | 0/3 [00:00<?, ?steps/s]
#  33%|███▎      | 1/3 [00:04<00:09,  4.74s/steps]
#  67%|██████▋   | 2/3 [00:06<00:03,  3.25s/steps]
# 100%|██████████| 3/3 [00:09<00:00,  2.77s/steps]
# 100%|██████████| 3/3 [00:09<00:00,  3.05s/steps]
# New video saved to Path: outputs/2026-08-12-14h56m12s_seed936862749_A polished 3D animated children's educational scene begins in a bright elementary-school classroom f.mp4
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
#
#   0%|          | 0/8 [00:00<?, ?steps/s]
#  12%|█▎        | 1/8 [00:04<00:31,  4.45s/steps]
#  25%|██▌       | 2/8 [00:06<00:17,  2.93s/steps]
#  38%|███▊      | 3/8 [00:08<00:12,  2.44s/steps]
#  50%|█████     | 4/8 [00:10<00:08,  2.21s/steps]
# [keepalive] Notebook cell still running…
#  62%|██████▎   | 5/8 [00:11<00:06,  2.08s/steps]
#  75%|███████▌  | 6/8 [00:13<00:04,  2.01s/steps]
#  88%|████████▊ | 7/8 [00:15<00:01,  1.96s/steps]
# 100%|██████████| 8/8 [00:17<00:00,  1.93s/steps]
# 100%|██████████| 8/8 [00:17<00:00,  2.18s/steps]
#
#   0%|          | 0/3 [00:00<?, ?steps/s]
#  33%|███▎      | 1/3 [00:10<00:20, 10.30s/steps]
#  67%|██████▋   | 2/3 [00:18<00:08,  8.80s/steps]
# 100%|██████████| 3/3 [00:25<00:00,  8.31s/steps]
# 100%|██████████| 3/3 [00:25<00:00,  8.59s/steps]
# [keepalive] Notebook cell still running…
# New video saved to Path: outputs/2026-08-12-14h58m38s_seed80692970_A polished 3D animated children's educational scene begins in a bright elementary-school classroom f.mp4
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
#
#   0%|          | 0/8 [00:00<?, ?steps/s]
#  12%|█▎        | 1/8 [00:05<00:35,  5.10s/steps]
#  25%|██▌       | 2/8 [00:07<00:21,  3.55s/steps]
#  38%|███▊      | 3/8 [00:10<00:15,  3.05s/steps]
#  50%|█████     | 4/8 [00:12<00:11,  2.82s/steps]
#  62%|██████▎   | 5/8 [00:14<00:08,  2.69s/steps]
#  75%|███████▌  | 6/8 [00:17<00:05,  2.61s/steps]
#  88%|████████▊ | 7/8 [00:19<00:02,  2.56s/steps]
# 100%|██████████| 8/8 [00:22<00:00,  2.53s/steps]
# 100%|██████████| 8/8 [00:22<00:00,  2.79s/steps]
#
#   0%|          | 0/3 [00:00<?, ?steps/s]
# [keepalive] Notebook cell still running…
#  33%|███▎      | 1/3 [00:13<00:27, 13.78s/steps]
#  67%|██████▋   | 2/3 [00:24<00:12, 12.23s/steps]
# 100%|██████████| 3/3 [00:36<00:00, 11.74s/steps]
# 100%|██████████| 3/3 [00:36<00:00, 12.03s/steps]
# New video saved to Path: outputs/2026-08-12-15h06m41s_seed909092852_A medium-wide continuous shot inside a bright, warm elementary school classroom, preserving the exac.mp4
#
# [keepalive] Notebook cell still running…
#   0%|          | 0/8 [00:00<?, ?steps/s]
#  12%|█▎        | 1/8 [00:04<00:33,  4.84s/steps]
#  25%|██▌       | 2/8 [00:07<00:19,  3.28s/steps]
#  38%|███▊      | 3/8 [00:09<00:13,  2.78s/steps]
#  50%|█████     | 4/8 [00:13<00:12,  3.20s/steps]
#  62%|██████▎   | 5/8 [00:15<00:08,  2.85s/steps]
#  75%|███████▌  | 6/8 [00:17<00:05,  2.62s/steps]
#  88%|████████▊ | 7/8 [00:19<00:02,  2.48s/steps]
# 100%|██████████| 8/8 [00:21<00:00,  2.39s/steps]
# 100%|██████████| 8/8 [00:21<00:00,  2.73s/steps]
#
#   0%|          | 0/3 [00:00<?, ?steps/s]
#  33%|███▎      | 1/3 [00:11<00:23, 11.80s/steps]
# [keepalive] Notebook cell still running…
#  67%|██████▋   | 2/3 [00:20<00:10, 10.25s/steps]
# 100%|██████████| 3/3 [00:30<00:00,  9.76s/steps]
# 100%|██████████| 3/3 [00:30<00:00, 10.05s/steps]
# New video saved to Path: outputs/2026-08-12-15h07m59s_seed509240384_A medium-wide continuous shot inside a bright, warm elementary school classroom, preserving the exac.mp4
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
#
#   0%|          | 0/8 [00:00<?, ?steps/s]
#  12%|█▎        | 1/8 [00:04<00:33,  4.84s/steps]
#  25%|██▌       | 2/8 [00:07<00:19,  3.28s/steps]
#  38%|███▊      | 3/8 [00:09<00:13,  2.78s/steps]
#  50%|█████     | 4/8 [00:11<00:10,  2.55s/steps]
#  62%|██████▎   | 5/8 [00:13<00:07,  2.42s/steps]
#  75%|███████▌  | 6/8 [00:15<00:04,  2.34s/steps]
#  88%|████████▊ | 7/8 [00:17<00:02,  2.29s/steps]
# 100%|██████████| 8/8 [00:20<00:00,  2.26s/steps]
# 100%|██████████| 8/8 [00:20<00:00,  2.52s/steps]
#
# [keepalive] Notebook cell still running…
#   0%|          | 0/3 [00:00<?, ?steps/s]
#  33%|███▎      | 1/3 [00:11<00:23, 11.77s/steps]
#  67%|██████▋   | 2/3 [00:20<00:10, 10.23s/steps]
# 100%|██████████| 3/3 [00:30<00:00,  9.75s/steps]
# 100%|██████████| 3/3 [00:30<00:00, 10.03s/steps]
# New video saved to Path: outputs/2026-08-12-15h14m15s_seed876522410_A medium-wide continuous shot inside the same bright, warm elementary school classroom, preserving t.mp4
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# Traceback (most recent call last):
#   File "/content/wan2gp/wgp.py", line 8301, in queue_worker_func
#     success = generate_media(task, send_cmd, plugin_data=plugin_data,  **filtered_params)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/wan2gp/wgp.py", line 7208, in generate_media
#     prefix_video  = preprocess_video(width=width, height=height,video_in=video_source, max_frames= parsed_keep_frames_video_source , start_frame = 0, fit_canvas= sample_fit_canvas, fit_crop = fit_crop, target_fps = fps, block_size = block_size, preserve_hdr=prefix_video_is_hdr )
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/wan2gp/wgp.py", line 5536, in preprocess_video
#     frames_list = get_resampled_video(video_in, start_frame, max_frames, target_fps, hdr_linear=hdr_input)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/wan2gp/wgp.py", line 5138, in get_resampled_video
#     return get_resampled_video_transparent(video_in, start_frame, max_frames, target_fps, bridge)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/wan2gp/shared/utils/utils.py", line 178, in get_resampled_video_transparent
#     return decode_video_frames_ffmpeg(video_in, start_frame, max_frames, target_fps=target_fps, bridge=bridge)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/wan2gp/shared/utils/video_decode.py", line 591, in decode_video_frames_ffmpeg
#     decoded = _decode_contiguous_video_frames_ffmpeg(video_path, decode_start, frame_nos[-1] - decode_start + 1, bridge, hdr_linear=hdr_linear)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/wan2gp/shared/utils/video_decode.py", line 479, in _decode_contiguous_video_frames_ffmpeg
#     raise RuntimeError(f"ffmpeg decode failed for {video_path}: {stderr}")
# RuntimeError: ffmpeg decode failed for outputs/2026-08-12-15h14m15s_seed876522410_A medium-wide continuous shot inside the same bright, warm elementary school classroom, preserving t.mp4: Unrecognized option 'fps_mode'.
# Error splitting the argument list: Option not found
# Error Queue autosaved successfully to error_queue.zip
# [keepalive] Notebook cell still running…
# Traceback (most recent call last):
#   File "/content/wan2gp/wgp.py", line 8301, in queue_worker_func
#     success = generate_media(task, send_cmd, plugin_data=plugin_data,  **filtered_params)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/wan2gp/wgp.py", line 7208, in generate_media
#     prefix_video  = preprocess_video(width=width, height=height,video_in=video_source, max_frames= parsed_keep_frames_video_source , start_frame = 0, fit_canvas= sample_fit_canvas, fit_crop = fit_crop, target_fps = fps, block_size = block_size, preserve_hdr=prefix_video_is_hdr )
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/wan2gp/wgp.py", line 5536, in preprocess_video
#     frames_list = get_resampled_video(video_in, start_frame, max_frames, target_fps, hdr_linear=hdr_input)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/wan2gp/wgp.py", line 5138, in get_resampled_video
#     return get_resampled_video_transparent(video_in, start_frame, max_frames, target_fps, bridge)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/wan2gp/shared/utils/utils.py", line 178, in get_resampled_video_transparent
#     return decode_video_frames_ffmpeg(video_in, start_frame, max_frames, target_fps=target_fps, bridge=bridge)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/wan2gp/shared/utils/video_decode.py", line 591, in decode_video_frames_ffmpeg
#     decoded = _decode_contiguous_video_frames_ffmpeg(video_path, decode_start, frame_nos[-1] - decode_start + 1, bridge, hdr_linear=hdr_linear)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/wan2gp/shared/utils/video_decode.py", line 479, in _decode_contiguous_video_frames_ffmpeg
#     raise RuntimeError(f"ffmpeg decode failed for {video_path}: {stderr}")
# RuntimeError: ffmpeg decode failed for /tmp/gradio/c37a1d798848e9bd2ea53e7f6cb67c837124f339b5e1c3e3e7cb61a7e600efd9/2026-08-12-15h14m15s_seed876522410_A medium-wide continuous shot inside the same bright, warm elementary school classroom, preserving t 1.mp4: Unrecognized option 'fps_mode'.
# Error splitting the argument list: Option not found
# Error Queue autosaved successfully to error_queue.zip
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
#
#   0%|          | 0/8 [00:00<?, ?steps/s]
#  12%|█▎        | 1/8 [00:04<00:33,  4.85s/steps]
#  25%|██▌       | 2/8 [00:07<00:19,  3.29s/steps]
#  38%|███▊      | 3/8 [00:09<00:13,  2.79s/steps]
#  50%|█████     | 4/8 [00:11<00:10,  2.55s/steps]
#  62%|██████▎   | 5/8 [00:13<00:07,  2.42s/steps]
#  75%|███████▌  | 6/8 [00:15<00:04,  2.34s/steps]
#  88%|████████▊ | 7/8 [00:17<00:02,  2.29s/steps]
# 100%|██████████| 8/8 [00:20<00:00,  2.26s/steps]
# 100%|██████████| 8/8 [00:20<00:00,  2.52s/steps]
#
#   0%|          | 0/3 [00:00<?, ?steps/s]
# [keepalive] Notebook cell still running…
#  33%|███▎      | 1/3 [00:11<00:23, 11.82s/steps]
#  67%|██████▋   | 2/3 [00:20<00:10, 10.25s/steps]
# 100%|██████████| 3/3 [00:30<00:00,  9.76s/steps]
# 100%|██████████| 3/3 [00:30<00:00, 10.05s/steps]
# New video saved to Path: outputs/2026-08-12-15h20m51s_seed15479556_A medium-wide continuous shot inside the same bright, warm elementary school classroom. Thỏ Mimi,.mp4
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
#
#   0%|          | 0/8 [00:00<?, ?steps/s]
#  12%|█▎        | 1/8 [00:05<00:39,  5.67s/steps]
#  25%|██▌       | 2/8 [00:07<00:21,  3.62s/steps]
#  38%|███▊      | 3/8 [00:10<00:14,  2.97s/steps]
#  50%|█████     | 4/8 [00:12<00:10,  2.67s/steps]
#  62%|██████▎   | 5/8 [00:14<00:07,  2.49s/steps]
#  75%|███████▌  | 6/8 [00:16<00:04,  2.39s/steps]
# [keepalive] Notebook cell still running…
#  88%|████████▊ | 7/8 [00:18<00:02,  2.33s/steps]
# 100%|██████████| 8/8 [00:21<00:00,  2.28s/steps]
# 100%|██████████| 8/8 [00:21<00:00,  2.63s/steps]
#
#   0%|          | 0/3 [00:00<?, ?steps/s]
#  33%|███▎      | 1/3 [00:11<00:23, 11.79s/steps]
#  67%|██████▋   | 2/3 [00:20<00:10, 10.24s/steps]
# 100%|██████████| 3/3 [00:30<00:00,  9.75s/steps]
# 100%|██████████| 3/3 [00:30<00:00, 10.04s/steps]
# [keepalive] Notebook cell still running…
# New video saved to Path: outputs/2026-08-12-15h26m26s_seed305325989_A single continuous medium-wide classroom shot. The classroom layout remains fixed throughout the en.mp4
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…

# %%
from google.colab import drive
drive.mount('/content/drive')
